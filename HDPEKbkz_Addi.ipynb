# %%
#Importing libraries
import matplotlib as mpl

# %config InlineBackend.figure_formats = ['svg']

mpl.rcParams.update(mpl.rcParamsDefault)
mpl.rcParams.update({'mathtext.fontset': 'cm'})
mpl.rcParams.update({'axes.labelsize': 22})
mpl.rcParams.update({'axes.titlesize': 16})
mpl.rcParams.update({'axes.linewidth': 0.5})
mpl.rcParams.update({'xtick.labelsize': 10})
mpl.rcParams.update({'ytick.labelsize': 10})

import matplotlib.pyplot as plt

# %matplotlib inline

import numpy as np #Needed for a bunch of mathematical operations.

# %%
import xlrd #Documentation on how to use xlrd @ https://openpyxl.readthedocs.io/en/stable/
import numpy as np

##Please send me an email if you need the data referenced in this cell
# I'm supposed to keep the origin of the data confidencial

#Extracting Data Experimental Data Excel File
workbook = xlrd.open_workbook('Practice_Data.xlsx')

#Setting up Model Parameters sheet
sheet_MP = workbook.sheet_by_name('MODEL PARAMETERS')

## Creating cell value range of the Maxwell Model Mode results
cell_range = sheet_MP.cell_value(2,3)
MaxModelModes = np.zeros((8,2))

for i in range(0,2):
    for j in range(0,8):
        
        JJ = sheet_MP.cell_value(j+2,i+4)
        JJ = float(JJ)
        MaxModelModes[j,i] = JJ
## MaxModelModes has lambdai and Gi in the first and second columns respectively. Lambda [=] sec, Gi [=] Pa
LambdA = MaxModelModes[:,0] # Array of the lambda values
GiRelax = MaxModelModes[:,1] # Array of the relaxtion modulus values


## If you only have the values from a table, just import them manually.
LambdA = [7.69e-4, 6.98e-3, 5.11e-2, 0.42, 4.30, 29.27]
GiRelax = [3.79e5, 1.40e5, 5.68e4, 1.84e4, 4.52e3, 1.25e3]


N = np.size(LambdA) # Number of modes of the maxwell model. This will be used below for integral calculation in the BKBZ model.

#The KBKZ is a big numerical integration to get the shear stress values basically. So we need to integrate from -infinity to t while summing over all the modes on this inside.

# %% [markdown]
# ## Defining the deformation tensors

# %%
# Defining the Cauchy and Finger Tensors here.

def Cauchy(G1, G2, strainType):
    #Defining the Cauchy strain tensor with strain at t1 =  gamma 1 and strain at t2 = gamma 2
    C = np.zeros((3,3))
    gamma1 = G1
    gamma2 = G2
    dif = gamma2 - gamma1
    if strainType == "Shear":
        C[0,0] = C[2,2] = 1
        C[0,1] = C[1,0] = dif
        C[1,1] = 1 + (dif)**2 
    elif strainType == 'Extension':
        C[0,0] = np.exp(2 * (dif))
        C[1,1] = C[2,2] = np.exp(-(dif))
    
    else :
        print('Remember to give a strain type')
    
    return C


def Finger(G1, G2, strainType):
    #Defining the Finger strain tensor with strain at t1 =  gamma 1 and strain at t2 = gamma 2
    B = np.zeros((3,3))
    gamma1 = G1
    gamma2 = G2
    dif = gamma1 - gamma2
    if strainType == "Shear":
        B[1,1] = B[2,2] = 1
        B[0,1] = dif 
        B[1,0] = dif
        B[0,0] = 1 + (dif)**2 
    elif strainType == 'Extension':
        B[0,0] = np.exp(2 * (dif))
        B[1,1] = B[2,2] = np.exp(-(dif))
    
    else :
        print('Remember to give a strain type')
    
    return B


# Getting the invariants of the strain tensors
def Invariants3by3(Tensor):
    # Takes any 3x3 matrix and calculates the invrariants of the matrix.
    # I will simply add the values as described in textbook. Rather than doing tedious calculations
    Inv1 = Tensor[0,0] + Tensor[1,1] + Tensor[2,2]
    Inv2 = Tensor[0,0]*Tensor[2,2] + Tensor[1,1]*Tensor[2,2] + Tensor[0,0]*Tensor[2,2] - Tensor[0,1]*Tensor[1,0] - Tensor[1,2]*Tensor[2,1] - Tensor[0,2]*Tensor[2,0]
    Inv3 = np.linalg.det(Tensor)
    return (Inv1,Inv2,Inv3)

# %% [markdown]
# ## Defining the strain

# %%
#For now we are only using start-up, so the gamma is easy to define

def gammaStartUpSS(gamma0,t):
    if t<0:
        return 0
    else:
        return (gamma0*t)

# %% [markdown]
# ## Writing out the important functions for the integration

# %%
def RelaxationMod(t):
    RelSum = 0
    for i in range(0,N):
        RelSum += (GiRelax[i]) * np.exp(-(t) / LambdA[i]) # Becareful of the definition of tend here!
    return RelSum

def MemoryMod(s):
    MemSum = 0
    for i in range(0,N):
        MemSum += (GiRelax[i]/LambdA[i]) * np.exp(-(s) / LambdA[i]) # Becareful of the definition of tend here!
    return MemSum

def DampingFunction(t,gamma0,StrainType):
    ##Note beta and alpha are global variable used when the function is first called!
    
    #Bring in the finger tensor
    StrainTensor = Finger(gammaStartUpSS(gamma0,t),gammaStartUpSS(gamma0,0),StrainType)
    #Calculate the invariants
    Inv1,Inv2,Inv3 = Invariants3by3(StrainTensor)
    I = beta*Inv1 + (1-beta)*Inv2 #Using the Papanastasiou Invariant
    damping = alpha/(I + (alpha-3)) #Calculating the damping value 
    return (damping)
    #print(damping)

# %% [markdown]
# ## Defining the integrated term and the front term from Eq. (X) of the report.

# %%
## Starting with the integrated term which is integrated from 0 to t for ds

def BKBZ_Int(s,gamma0,StrainType):
    #Get the memory modulus sum for the current value of s
    Term1 = MemoryMod(s)
    #Get the damping function
    Term2 = DampingFunction(s,gamma0,StrainType)
    # Getting the strain from the correct position in the deformation tensor.
    B = Finger(gammaStartUpSS(gamma0,s),gammaStartUpSS(gamma0,0),StrainType)
    C = Cauchy(gammaStartUpSS(gamma0,s),gammaStartUpSS(gamma0,0),StrainType)
    if StrainType == 'Extension': #row in the stress tensor. Can be from 0 to 2
        row = 0
        col = 0
        Term3 = (B[row,col] - B[row+1,col+1]) + theta*(C[row,col] - C[row+1,col+1])#*gamma0
    elif StrainType == 'Shear':
        row=1
        col =0
        Term3 = B[row,col] + theta*C[row,col]#*gamma0
    Fin = Term1*Term2*Term3/(1-theta)
    return Fin

def BKBZ_Front(t,gamma0,StrainType):
    #Get the relaxation modulus sum for the current value of t
    Term1 = RelaxationMod(t)
    #Get the damping function
    Term2 = DampingFunction(t,gamma0,StrainType)
    # Getting the strain from the correct position in the deformation tensor.
    B = Finger(gammaStartUpSS(gamma0,t),gammaStartUpSS(gamma0,0),StrainType)
    C = Cauchy(gammaStartUpSS(gamma0,t),gammaStartUpSS(gamma0,0),StrainType)
    if StrainType == 'Extension': #row in the stress tensor. Can be from 0 to 2
        row = 0
        col = 0
        Term3 = (B[row,col] - B[row+1,col+1]) + theta*(C[row,col] - C[row+1,col+1])
    elif StrainType == 'Shear':
        row=1
        col =0
        Term3 = B[row,col] + theta*C[row,col]
    Fin = Term1*Term2*Term3/(1-theta)
    return Fin

# %% [markdown]
# ## Writting out a function that integrates BKBZ_Int using romberg integration

# %%
def Romber_BKBZ(t,tprev,gamma0,StrainType,tol = 1e-6,maxit = 10):
    tstart = tprev
    # Initialize the Romberg Matrix
    I = np.zeros((maxit+1,maxit+1))
    # Initialization
    n = 1
    tarray = np.linspace(tstart,t)
    dt = (t - tstart) / n
    II = 0
    for i in range(0,n): #Simple trapz integration
        II += (BKBZ_Int(tarray[i],gamma0,StrainType) + BKBZ_Int(tarray[i+1],gamma0,StrainType))*dt/2
    I[0,0] = II
    iter = 0
    
    ## Loop until convergence or maxit is attained
    while ( iter < maxit ):
        iter += 1

        # Divide h by 2 at each iteration and get new time interval
        n = 2**iter
        tarray = np.linspace(tstart,t,n+1)    
        dt = (t - tstart) / n
        # Compute an approximation with trapezoidal rule with h = ( b - a ) / 2^iter
        II = 0
        for i in range(0,n):
             II+= (BKBZ_Int(tarray[i],gamma0,StrainType)+BKBZ_Int(tarray[i+1],gamma0,StrainType))*dt/2
        I[iter,0] = II
        # Compute the improved estimates at each level
        for k in range(1,iter+1):
            j = iter - k;
            I[j,k] = ( 4**k * I[j+1,k-1] - I[j,k-1] ) / ( 4**k - 1 )

            # Compute relative error and check convergence
        ea = np.abs( ( I[0,iter] - I[1,iter-1] ) / I[0,iter] )
        if ea < tol: break

        integral = I[0,iter]
        
        niter = iter
    return(integral)

# %% [markdown]
# ## Now we can use what we have to calculate for the start up viscosity

# %%
## Defining fitting parameters
import time
tic = time.perf_counter()




alpha = 11.8
beta = 1.0
theta = -0.5

## Define StrainType and gamma0
StrainType = input('What is the strain type? Shear or Extension')
P = int(input('How many shear rates/extensional rates to calculate? (integer)'))
gamma0 = np.zeros(P)
for j in range(0,P):
    print('Input the shear rate',j+1)
    gamma0[j] = input('Input the shear rates/extensional rate')



## Creating the time interval
tt = np.logspace(-2,2,200)


#Initializing
Int = np.zeros((len(tt),P))
for p in range(0,P):
    FrontPrev = 0
    TegPrev = 0
    IntPrev = 0
    tPrev = 0
    for i in range(0,len(tt)):
        Front = BKBZ_Front(tt[i],float(gamma0[p]),StrainType)
        Teg = Romber_BKBZ(tt[i],tPrev,float(gamma0[p]),StrainType,tol = 1e-10,maxit = 10)
        Int[i,p] = IntPrev + (Front-FrontPrev + Teg)/float(gamma0[p])
        FrontPrev= Front
        IntPrev = Int[i,p]
        tPrev = tt[i]
        
        
        
CC = ['red','black','green','blue','yellow','cyan'] #range of colours to use    
fig, ax = plt.subplots(figsize=(6, 6))
for p in range(0,P):
    ax.plot( tt, Int[:,p],  color=CC[p], label= gamma0[p] )

ax.set_xlabel('Time (s)')
ax.set_ylabel('Tensile stress growth (Pa*s)')
ax.set_yscale('log')
ax.set_xscale('log')
ax.axis([0.01, 1e2, 1000, 1e6])
ax.set_title('KBKZ Prediction')
ax.legend(loc='best',title='Legend')
ax.grid()  
toc = time.perf_counter()
print(f'Time to solution = {toc - tic:.8f} seconds')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-d2081dd796b9> in <module>
#      11
#      12 ## Define StrainType and gamma0
# ---> 13 StrainType = input('What is the strain type? Shear or Extension')
#      14 P = int(input('How many shear rates/extensional rates to calculate? (integer)'))
#      15 gamma0 = np.zeros(P)
#
# C:\Anaconda\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# C:\Anaconda\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
def StressRelaxation(gamma,t):
    StrainType = 'Shear'
    T1 = DampingRelax(gamma,StrainType)
    T2 = RelaxationMod(t)
    SR = T1*T2
    return(SR)

def DampingRelax(gamma,StrainType):
    ##Note beta and alpha are global variable used when the function is first called!
    
    #Bring in the finger tensor
    StrainTensor = Finger(gamma,0,StrainType)
    #Calculate the invariants
    Inv1,Inv2,Inv3 = Invariants3by3(StrainTensor)
    I = beta*Inv1 + (1-beta)*Inv2 #Using the Papanastasiou Invariant
    damping = alpha/(I + (alpha-3)) #Calculating the damping value 
    return (damping)

# %%
alpha = 11.8
beta = 1.0
theta = -0.5

gamma = ['0.05', '0.1', '0.2', '0.5', '1.', '2.', '5.', '10.']
P = len(gamma)
tt = np.logspace(-1,2,50)
Stress = np.zeros((len(tt),P))
for p in range(0,P):
    for i in range(0,len(tt)):
        Stress[i,p] = StressRelaxation(float(gamma[p]),tt[i])

        
CC = ['red','black','green','blue','yellow','cyan','orange','magenta'] #range of colours to use 
fig, ax = plt.subplots(figsize=(6, 6))
for p in range(0,P):
    ax.scatter( tt, Stress[:,p], color= CC[p], label= gamma[p] )

ax.set_xlabel('Time (s)')
ax.set_ylabel('Relaxation Modulus, G(Pa)')
ax.set_yscale('log')
ax.set_xscale('log')
ax.axis([0.02, 1e2, 10, 1e5])
ax.set_title('KBKZ Prediction of Step Strain Shear')
ax.legend(loc='best',title='Legend')
ax.grid()

# %%
print(Stress)
# Out:
# [[2.81827153e+04 2.81648178e+04 2.80934542e+04 2.76038587e+04
#   2.59864451e+04 2.10523100e+04 9.03876353e+03 2.97519229e+03]
#  [2.55958121e+04 2.55795573e+04 2.55147443e+04 2.50700890e+04
#   2.36011384e+04 1.91199096e+04 8.20909163e+03 2.70209814e+03]
#  [2.32842956e+04 2.32695088e+04 2.32105489e+04 2.28060497e+04
#   2.14697577e+04 1.73932215e+04 7.46774183e+03 2.45807602e+03]
#  [2.12591754e+04 2.12456747e+04 2.11918427e+04 2.08225243e+04
#   1.96024545e+04 1.58804695e+04 6.81824505e+03 2.24428817e+03]
#  [1.95081693e+04 1.94957806e+04 1.94463825e+04 1.91074829e+04
#   1.79879038e+04 1.45724790e+04 6.25666219e+03 2.05943800e+03]
#  [1.79975708e+04 1.79861413e+04 1.79405683e+04 1.76279111e+04
#   1.65950257e+04 1.34440714e+04 5.77218285e+03 1.89996716e+03]
#  [1.66782102e+04 1.66676186e+04 1.66253865e+04 1.63356495e+04
#   1.53784825e+04 1.24585175e+04 5.34903739e+03 1.76068494e+03]
#  [1.54944664e+04 1.54846265e+04 1.54453918e+04 1.51762190e+04
#   1.42869874e+04 1.15742683e+04 4.96938693e+03 1.63571949e+03]
#  [1.43941945e+04 1.43850534e+04 1.43486048e+04 1.40985461e+04
#   1.32724594e+04 1.07523722e+04 4.61650763e+03 1.51956602e+03]
#  [1.33369846e+04 1.33285149e+04 1.32947433e+04 1.30630507e+04
#   1.22976376e+04 9.96264311e+03 4.27743916e+03 1.40795851e+03]
#  [1.22987242e+04 1.22909139e+04 1.22597714e+04 1.20461156e+04
#   1.13402885e+04 9.18706917e+03 3.94444817e+03 1.29835146e+03]
#  [1.12718569e+04 1.12646987e+04 1.12361564e+04 1.10403395e+04
#   1.03934446e+04 8.42000578e+03 3.61511118e+03 1.18994715e+03]
#  [1.02622727e+04 1.02557556e+04 1.02297697e+04 1.00514915e+04
#   9.46253696e+03 7.66585273e+03 3.29131720e+03 1.08336738e+03]
#  [9.28460328e+03 9.27870705e+03 9.25519681e+03 9.09390292e+03
#   8.56105705e+03 6.93553989e+03 2.97775897e+03 9.80156800e+02]
#  [8.35750426e+03 8.35219678e+03 8.33103412e+03 8.18584597e+03
#   7.70620656e+03 6.24300278e+03 2.68041967e+03 8.82284830e+02]
#  [7.49969746e+03 7.49493473e+03 7.47594419e+03 7.34565803e+03
#   6.91524838e+03 5.60222653e+03 2.40530378e+03 7.91727900e+02]
#  [6.72684791e+03 6.72257599e+03 6.70554244e+03 6.58868236e+03
#   6.20262675e+03 5.02491281e+03 2.15743539e+03 7.10139736e+02]
#  [6.04914866e+03 6.04530711e+03 6.02998961e+03 5.92490266e+03
#   5.57774039e+03 4.51867576e+03 1.94008361e+03 6.38596396e+02]
#  [5.46966452e+03 5.46619099e+03 5.45234084e+03 5.35732079e+03
#   5.04341528e+03 4.08580478e+03 1.75423140e+03 5.77421427e+02]
#  [4.98369312e+03 4.98052820e+03 4.96790862e+03 4.88133095e+03
#   4.59531547e+03 3.72278722e+03 1.59837060e+03 5.26118408e+02]
#  [4.57940642e+03 4.57649825e+03 4.56490239e+03 4.48534807e+03
#   4.22253471e+03 3.42078761e+03 1.46870773e+03 4.83438679e+02]
#  [4.23980262e+03 4.23711011e+03 4.22637419e+03 4.15271954e+03
#   3.90939612e+03 3.16710572e+03 1.35978996e+03 4.47587392e+02]
#  [3.94562068e+03 3.94311499e+03 3.93312399e+03 3.86457992e+03
#   3.63813969e+03 2.94735368e+03 1.26543989e+03 4.16531199e+02]
#  [3.67852167e+03 3.67618560e+03 3.66687094e+03 3.60296697e+03
#   3.39185562e+03 2.74783240e+03 1.17977587e+03 3.88334096e+02]
#  [3.42371188e+03 3.42153763e+03 3.41286820e+03 3.35339083e+03
#   3.15690308e+03 2.55749110e+03 1.09805325e+03 3.61434342e+02]
#  [3.17138673e+03 3.16937272e+03 3.16134222e+03 3.10624829e+03
#   2.92424155e+03 2.36900581e+03 1.01712750e+03 3.34796886e+02]
#  [2.91684284e+03 2.91499049e+03 2.90760453e+03 2.85693258e+03
#   2.68953419e+03 2.17886314e+03 9.35490153e+02 3.07925203e+02]
#  [2.65959650e+03 2.65790751e+03 2.65117295e+03 2.60496993e+03
#   2.45233497e+03 1.98670175e+03 8.52986078e+02 2.80768226e+02]
#  [2.40209000e+03 2.40056454e+03 2.39448203e+03 2.35275246e+03
#   2.21489587e+03 1.79434602e+03 7.70398565e+02 2.53583785e+02]
#  [2.14847312e+03 2.14710873e+03 2.14166842e+03 2.10434474e+03
#   1.98104329e+03 1.60489583e+03 6.89058534e+02 2.26809965e+02]
#  [1.90365991e+03 1.90245098e+03 1.89763058e+03 1.86455984e+03
#   1.75530829e+03 1.42202190e+03 6.10542013e+02 2.00965528e+02]
#  [1.67261756e+03 1.67155535e+03 1.66731999e+03 1.63826296e+03
#   1.54227099e+03 1.24943473e+03 5.36442084e+02 1.76574854e+02]
#  [1.45977070e+03 1.45884367e+03 1.45514728e+03 1.42978786e+03
#   1.34601123e+03 1.09043948e+03 4.68177819e+02 1.54105042e+02]
#  [1.26846292e+03 1.26765738e+03 1.26444541e+03 1.24240943e+03
#   1.16961200e+03 9.47533774e+02 4.06821566e+02 1.33909066e+02]
#  [1.10050870e+03 1.09980982e+03 1.09702314e+03 1.07790489e+03
#   1.01474640e+03 8.22073036e+02 3.52955271e+02 1.16178479e+02]
#  [9.55926577e+02 9.55319511e+02 9.52898938e+02 9.36292401e+02
#   8.81431518e+02 7.14071103e+02 3.06584876e+02 1.00915236e+02]
#  [8.32948410e+02 8.32419442e+02 8.30310271e+02 8.15840134e+02
#   7.68037001e+02 6.22207191e+02 2.67143305e+02 8.79326799e+01]
#  [7.28353150e+02 7.27890605e+02 7.26046288e+02 7.13393199e+02
#   6.71592816e+02 5.44075193e+02 2.33597501e+02 7.68907697e+01]
#  [6.38087138e+02 6.37681917e+02 6.36066169e+02 6.24981199e+02
#   5.88361207e+02 4.76647053e+02 2.04647376e+02 6.73615693e+01]
#  [5.58035816e+02 5.57681433e+02 5.56268388e+02 5.46574085e+02
#   5.14548259e+02 4.16849223e+02 1.78973308e+02 5.89107130e+01]
#  [4.84746848e+02 4.84439007e+02 4.83211543e+02 4.74790429e+02
#   4.46970677e+02 3.62102827e+02 1.55468062e+02 5.11737448e+01]
#  [4.15912603e+02 4.15648476e+02 4.14595313e+02 4.07370000e+02
#   3.83500664e+02 3.10684082e+02 1.33391535e+02 4.39070528e+01]
#  [3.50508512e+02 3.50285920e+02 3.49398371e+02 3.43309271e+02
#   3.23193493e+02 2.61827640e+02 1.12415128e+02 3.70024751e+01]
#  [2.88612869e+02 2.88429584e+02 2.87698766e+02 2.82684929e+02
#   2.66121358e+02 2.15591987e+02 9.25639508e+01 3.04682772e+01]
#  [2.31034356e+02 2.30887637e+02 2.30302617e+02 2.26289045e+02
#   2.13029921e+02 1.72581202e+02 7.40973638e+01 2.43898299e+01]
#  [1.78896619e+02 1.78783009e+02 1.78330012e+02 1.75222186e+02
#   1.64955261e+02 1.33634642e+02 5.73757429e+01 1.88857544e+01]
#  [1.33282355e+02 1.33197713e+02 1.32860219e+02 1.30544812e+02
#   1.22895702e+02 9.95610753e+01 4.27463312e+01 1.40703487e+01]
#  [9.49742474e+01 9.49139336e+01 9.46734422e+01 9.30235316e+01
#   8.75729340e+01 7.09451617e+01 3.04601510e+01 1.00262393e+01]
#  [6.42927155e+01 6.42518861e+01 6.40890857e+01 6.29721805e+01
#   5.92824043e+01 4.80262516e+01 2.06199667e+01 6.78725201e+00]
#  [4.10265585e+01 4.10005043e+01 4.08966179e+01 4.01838968e+01
#   3.78293716e+01 3.06465795e+01 1.31580423e+01 4.33109084e+00]]

# %%
import time
tic = time.perf_counter()




alpha = 11.8
beta = 1.0
theta = -0.5

## Define StrainType and gamma0
StrainType = 'Shear'
P = int(input('How many shear rates/extensional rates to calculate? (integer)'))
gamma0 = np.zeros(P)
for j in range(0,P):
    print('Input the shear rate',j+1)
    gamma0[j] = input('Input the shear rates/extensional rate')



## Creating the time interval
tt = np.logspace(-2,4,40)


#Initializing
Int = np.zeros((len(tt),P))
for p in range(0,P):
    TegPrev = 0
    IntPrev = 0
    tPrev = 0
    for i in range(0,len(tt)):
        Teg = Romber_BKBZ(tt[i],tPrev,float(gamma0[p]),StrainType,tol = 1e-10,maxit = 10)
        Int[i,p] = IntPrev +  (Teg)
        IntPrev = Int[i,p]
        tPrev = tt[i]
        
        
        
CC = ['red','black','green','blue','yellow','cyan'] #range of colours to use    
fig, ax = plt.subplots(figsize=(6, 6))
gamma= np.zeros(P)
for p in range(0,P):
    gamma[p] = float(gamma0[p])

ax.plot( gamma, Int[-1,:],  color='red' )

ax.set_xlabel('Shear Rate [1/s]')
ax.set_ylabel('Stress [Pa]')

#ax.axis([0.01, 1e4, 1000, 1e6])
ax.set_title('KBKZ Prediction of Flow Curve')

ax.grid()  
ax.set_yscale('log')
ax.set_xscale('log')
toc = time.perf_counter()
print(f'Time to solution = {toc - tic:.8f} seconds')
# Out:
# How many shear rates/extensional rates to calculate? (integer) 6
# Input the shear rate 1
# Input the shear rates/extensional rate 0.001
# Input the shear rate 2
# Input the shear rates/extensional rate 0.01
# Input the shear rate 3
# Input the shear rates/extensional rate 0.1
# Input the shear rate 4
# Input the shear rates/extensional rate 1
# Input the shear rate 5
# Input the shear rates/extensional rate 5
# Input the shear rate 6
# Input the shear rates/extensional rate 20
# Time to solution = 19.11555060 seconds
